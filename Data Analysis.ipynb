# %%
import pandas as pd

# %%
GDP = pd.read_csv("Data/GDP.csv")

# %%
world_GDP = pd.DataFrame(GDP.loc[GDP['Country Name']=="World"])
world_GDP=world_GDP.drop(["Region","IncomeGroup","Country Code"],axis = 1)

# %%
world_GDP.transpose().to_csv("Data/world.csv")

# %%
world = pd.read_csv("Data/world.csv")

# %%
world.pct_change().to_csv("Data/world_pct.csv")

# %%
GDP = GDP.drop(['Unnamed: 0',],axis = 1)

# %%
GDP_by_continent = GDP.groupby(by="Region").sum()
GDP_by_group = GDP.groupby(by="IncomeGroup").sum()

# %%
Population = pd.read_csv("Data/Pop.csv")

# %%
GDP
# Out:
#                     Country Name Country Code          1960          1961  \
# 0                          Aruba          ABW           NaN           NaN
# 1    Africa Eastern and Southern          AFE  2.129059e+10  2.180847e+10
# 2                    Afghanistan          AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central          AFW  1.040414e+10  1.112789e+10
# 4                         Angola          AGO           NaN           NaN
# ..                           ...          ...           ...           ...
# 260                       Kosovo          XKX           NaN           NaN
# 261                  Yemen, Rep.          YEM           NaN           NaN
# 262                 South Africa          ZAF  8.748597e+09  9.225996e+09
# 263                       Zambia          ZMB  7.130000e+08  6.962857e+08
# 264                     Zimbabwe          ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
Population = Population.drop(['Unnamed: 0',],axis = 1)

# %%
Population_by_continent = Population.groupby(by="Region").sum()
Population_by_group = Population.groupby(by="IncomeGroup").sum()

# %%
Population_by_continent.transpose().to_csv("Data/Pop_Continent.csv")

# %%
continent_GDP = GDP_by_continent.div(Population_by_continent)

# %%
continent_GDP.transpose().to_csv("Data/GDP_Continent.csv")

# %%
GDP_df = pd.read_csv("case study/GDP/GDP.csv")
Pop_df = pd.read_csv("case study/Population/Population.csv")

# %%
GDP_df = GDP_df.drop(['Country Code','Indicator Name','Indicator Code','Unnamed: 66'], axis =1)
Pop_df= Pop_df.drop(['Country Code','Indicator Name','Indicator Code','Unnamed: 66'], axis =1)

# %%
GDP_df = GDP_df.set_index('Country Name')
Pop_df = Pop_df.set_index('Country Name')

# %%
GDPperCapita=GDP_df.div(Pop_df)

# %%
GDPperCapita.to_csv("Data/GDP_per_Capita.csv")

# %%
GDP_pct = continent_GDP.transpose().pct_change().transpose()

# %%
GDP_pct.transpose()
# Out:
# Region  East Asia & Pacific  Europe & Central Asia  Latin America & Caribbean  \
# 1960                    NaN                    NaN                        NaN
# 1961               0.004591               0.050328                   0.031320
# 1962               0.006028               0.078881                   0.444852
# 1963               0.089194               0.092178                  -0.007880
# 1964               0.120606               0.093505                   0.079101
# ...                     ...                    ...                        ...
# 2017               0.060126               0.055630                   0.100426
# 2018               0.083299               0.067218                  -0.031145
# 2019               0.015368              -0.015143                  -0.023009
# 2020              -0.003107              -0.039947                  -0.164235
# 2021               0.133796               0.129903                   0.089885
#
# ...

# %%
GDP_pct.transpose().to_csv("Data/continent_Pct_change.csv")
